# %% [markdown]
# # Домашнее задание 2 (оцениваемое)

# %% [markdown]
# ## Задание 1
#
# Дан текст (можно взять любой, необязательно этот):
#
# "варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг"
#
# Необходимо выделить все биграммы в этом тексте и сохранить их список в какую-либо переменную. Биграммы -- это пары стоящих рядом слов, например, "варкалось хливкие", "хливкие шорьки" и т.д.
#
# Подсказка №1: текст нужно разбить на слова с помощью функции split(), а потом использовать цикл for для создания списка биграмм. На каждой итерации цикла нужно печатать биграмму, а потом добавлять ее в список.
#
# Подсказка №2: количество биграмм в тексте = количество слов в тексте - 1.

# %%
poem = 'варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг'.split() 

Bigrlist = []

for i in range(len(poem)-1):
    bigram = (poem[i:i+2])
    Bigrlist.append(bigram)
print (Bigrlist)
# Out:
# [['варкалось', 'хливкие'], ['хливкие', 'шорьки'], ['шорьки', 'пырялись'], ['пырялись', 'по'], ['по', 'наве'], ['наве', 'и'], ['и', 'хрюкотали'], ['хрюкотали', 'зелюки'], ['зелюки', 'как'], ['как', 'мюмзики'], ['мюмзики', 'в'], ['в', 'мове'], ['мове', 'о'], ['о', 'бойся'], ['бойся', 'бармаглота'], ['бармаглота', 'сын'], ['сын', 'он'], ['он', 'так'], ['так', 'свирлеп'], ['свирлеп', 'и'], ['и', 'дик'], ['дик', 'а'], ['а', 'в'], ['в', 'глyще'], ['глyще', 'рымит'], ['рымит', 'исполин'], ['исполин', 'злопастный'], ['злопастный', 'брандашмыг']]

# %% [markdown]
# ## Задание 2
# Если вы не делали git pull или git clone: cкачать архив с текстовыми файлами отсюда и распаковать его. Если делали, то все нужные файлы уже есть в папке poems.
# Распечатать текущую директорию и список всех файлов и папок в ней. Посчитать и распечатать количество файлов.
# Пройтись циклом по рабочей директории, читая содержимое каждого файла и записывая его в новый файл poems.txt По завершении цикла должен получиться файл со всеми стихотворениями!

# %%
import os

# %%
print(os.getcwd()) #узнаем текущую директорию
# Out:
# C:\Users\asus\Desktop\DH 18-19\python-dh-hw

# %%
for file in os.listdir('.'): # узнаем файлы и папки в текущей директории
    print(file)
# Out:
# .git
# .ipynb_checkpoints
# HW1.ipynb
# HW2.ipynb
# poems
# poems.rar
# README.md
# боль.txt

# %%
print ("Количество файлов в директории: ", len([name for name in os.listdir('.') if os.path.isfile(name)]))
# Out:
# Колиечство файлов в директории:  5

# %% [markdown]
# ## Задание 3
#
# ### Удивительная кошка
#
# *Несчастная кошка порезала лапу-
# Сидит, и ни шагу не может ступить.
# Скорей, чтобы вылечить кошкину лапу
# Воздушные шарики надо купить!*
#
# *И сразу столпился народ на дороге-
# Шумит, и кричит, и на кошку глядит.
# А кошка отчасти идет по дороге,
# Отчасти по воздуху плавно летит!*
#
# 1. Скопировать текст, сохранить его в переменную.
# 2. Узнать длину текста в символах.
# 3. Очистить текст от пунктуации, используя list compehensions. На выходе должен получиться список слов.
# 4. Объединить слова из получившегося списка в строку через пробел.
# 5. С помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру. На выходе должен получиться список из всех слов стихотворения, написанных с маленькой буквы (не только те, которые изначально были с маленькой буквы, а все).
# 6. Узнать длину текста в словах.
# 7. Узнать количество уникальных слов.
# 8. Распечатать последние 10 слов.
# 9. Соединить полученный в пункте 3 список в строку. Слова в строке должны быть написаны через знак переноса строки.
# 10. Распечатать с 20 по 30 символ этой строки (включительно).
# 11. Разбить текст на биграммы, записать их в переменную и посчитать частотность каждой биграммы. Биграммы должны быть в виде списка кортежей.
#
# **Подсказка №1** -- это пары стоящих рядом слов, например, "варкалось хливкие", "хливкие шорьки" и т.д.
#
# **Подсказка №2:** количество биграмм в тексте = количество слов в тексте - 1.

# %%
catpoem = """Удивительная кошка
Несчастная кошка порезала лапу-
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!"""

#узнаем длину текста в символах
print("Количество символов: ", len(catpoem))
# Out:
# Количество символов:  288

# %%
# очищаем от пунктуации 
from string import punctuation 
words = catpoem.split()
words = [w.strip(punctuation) for w in words]
print (words)
# Out:
# ['Удивительная', 'кошка', 'Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
# объединяем слова в строку через пробел 
J = " ".join(words)
print (J)
# Out:
# Удивительная кошка Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит

# %%
# проверяем слова и приводим все слова к нижнему регистру
Lreg = ([ w if w.islower() else w.lower() for w in words])
print (Lreg)
# Out:
# ['удивительная', 'кошка', 'несчастная', 'кошка', 'порезала', 'лапу', 'сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'воздушные', 'шарики', 'надо', 'купить', 'и', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'а', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
# Узнаем длину текста в словах
print ("Количество слов: " + str (len (words)))
# Out:
# Количество слов: 46

# %%
# Распечатать последние 10 слов.
print ("Последние 10 слов: " , Lreg [36:46])
# Out:
# Последние 10 слов:  ['кошка', 'отчасти', 'идет', 'по', 'дороге', 'отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
# Узнаем количество уникальных слов.
original = set(Lreg)
print('Количество уникальных слов : ', len(original))
# Out:
# Количество уникальных слов :  36

# %%
# или вот так
original_words = []

for word in Lreg:
        if word in original_words:    
            pass    
        else:
            original_words.append(word)    
print ('Количество уникальных слов : ', len (original_words))
# Out:
# Количество уникальных слов :  36

# %%
# Соединить полученный в пункте 3 список в строку. 
# Слова в строке должны быть написаны через знак переноса строки.
Stroka = "\n".join(words)
print (Stroka)
# Out:
# Удивительная
# кошка
# Несчастная
# кошка
# порезала
# лапу
# Сидит
# и
# ни
# шагу
# не
# может
# ступить
# Скорей
# чтобы
# вылечить
# кошкину
# лапу
# Воздушные
# шарики
# надо
# купить
# И
# сразу
# столпился
# народ
# на
# дороге
# Шумит
# и
# кричит
# и
# на
# кошку
# глядит
# А
# кошка
# отчасти
# идет
# по
# дороге
# Отчасти
# по
# воздуху
# плавно
# летит

# %%
# Распечатать с 20 по 30 символ этой строки (включительно)
print ("С 20 по 30 символ строки: " , Stroka [21:31])
# Out:
# С 20 по 30 символ строки:  счастная
# к

# %%
# Разбиваем текст на биграммы, записываем их в переменную

bigrams = [Lreg[l:l+2] for l in range(len(Lreg)-1)]
print (bigrams)

for b in bigrams: # считаем количество биграмм
    print("Биграмма " + str (b) +  " встречается в тексте " + str (bigrams.count(b)) + " раз(a)." )
# Out:
# [['удивительная', 'кошка'], ['кошка', 'несчастная'], ['несчастная', 'кошка'], ['кошка', 'порезала'], ['порезала', 'лапу'], ['лапу', 'сидит'], ['сидит', 'и'], ['и', 'ни'], ['ни', 'шагу'], ['шагу', 'не'], ['не', 'может'], ['может', 'ступить'], ['ступить', 'скорей'], ['скорей', 'чтобы'], ['чтобы', 'вылечить'], ['вылечить', 'кошкину'], ['кошкину', 'лапу'], ['лапу', 'воздушные'], ['воздушные', 'шарики'], ['шарики', 'надо'], ['надо', 'купить'], ['купить', 'и'], ['и', 'сразу'], ['сразу', 'столпился'], ['столпился', 'народ'], ['народ', 'на'], ['на', 'дороге'], ['дороге', 'шумит'], ['шумит', 'и'], ['и', 'кричит'], ['кричит', 'и'], ['и', 'на'], ['на', 'кошку'], ['кошку', 'глядит'], ['глядит', 'а'], ['а', 'кошка'], ['кошка', 'отчасти'], ['отчасти', 'идет'], ['идет', 'по'], ['по', 'дороге'], ['дороге', 'отчасти'], ['отчасти', 'по'], ['по', 'воздуху'], ['воздуху', 'плавно'], ['плавно', 'летит']]
# Биграмма ['удивительная', 'кошка'] встречается в тексте 1 раз(a).
# Биграмма ['кошка', 'несчастная'] встречается в тексте 1 раз(a).
# Биграмма ['несчастная', 'кошка'] встречается в тексте 1 раз(a).
# Биграмма ['кошка', 'порезала'] встречается в тексте 1 раз(a).
# Биграмма ['порезала', 'лапу'] встречается в тексте 1 раз(a).
# Биграмма ['лапу', 'сидит'] встречается в тексте 1 раз(a).
# Биграмма ['сидит', 'и'] встречается в тексте 1 раз(a).
# Биграмма ['и', 'ни'] встречается в тексте 1 раз(a).
# Биграмма ['ни', 'шагу'] встречается в тексте 1 раз(a).
# Биграмма ['шагу', 'не'] встречается в тексте 1 раз(a).
# Биграмма ['не', 'может'] встречается в тексте 1 раз(a).
# Биграмма ['может', 'ступить'] встречается в тексте 1 раз(a).
# Биграмма ['ступить', 'скорей'] встречается в тексте 1 раз(a).
# Биграмма ['скорей', 'чтобы'] встречается в тексте 1 раз(a).
# Биграмма ['чтобы', 'вылечить'] встречается в тексте 1 раз(a).
# Биграмма ['вылечить', 'кошкину'] встречается в тексте 1 раз(a).
# Биграмма ['кошкину', 'лапу'] встречается в тексте 1 раз(a).
# Биграмма ['лапу', 'воздушные'] встречается в тексте 1 раз(a).
# Биграмма ['воздушные', 'шарики'] встречается в тексте 1 раз(a).
# Биграмма ['шарики', 'надо'] встречается в тексте 1 раз(a).
# Биграмма ['надо', 'купить'] встречается в тексте 1 раз(a).
# Биграмма ['купить', 'и'] встречается в тексте 1 раз(a).
# Биграмма ['и', 'сразу'] встречается в тексте 1 раз(a).
# Биграмма ['сразу', 'столпился'] встречается в тексте 1 раз(a).
# Биграмма ['столпился', 'народ'] встречается в тексте 1 раз(a).
# Биграмма ['народ', 'на'] встречается в тексте 1 раз(a).
# Биграмма ['на', 'дороге'] встречается в тексте 1 раз(a).
# Биграмма ['дороге', 'шумит'] встречается в тексте 1 раз(a).
# Биграмма ['шумит', 'и'] встречается в тексте 1 раз(a).
# Биграмма ['и', 'кричит'] встречается в тексте 1 раз(a).
# Биграмма ['кричит', 'и'] встречается в тексте 1 раз(a).
# Биграмма ['и', 'на'] встречается в тексте 1 раз(a).
# Биграмма ['на', 'кошку'] встречается в тексте 1 раз(a).
# Биграмма ['кошку', 'глядит'] встречается в тексте 1 раз(a).
# Биграмма ['глядит', 'а'] встречается в тексте 1 раз(a).
# Биграмма ['а', 'кошка'] встречается в тексте 1 раз(a).
# Биграмма ['кошка', 'отчасти'] встречается в тексте 1 раз(a).
# Биграмма ['отчасти', 'идет'] встречается в тексте 1 раз(a).
# Биграмма ['идет', 'по'] встречается в тексте 1 раз(a).
# Биграмма ['по', 'дороге'] встречается в тексте 1 раз(a).
# Биграмма ['дороге', 'отчасти'] встречается в тексте 1 раз(a).
# Биграмма ['отчасти', 'по'] встречается в тексте 1 раз(a).
# Биграмма ['по', 'воздуху'] встречается в тексте 1 раз(a).
# Биграмма ['воздуху', 'плавно'] встречается в тексте 1 раз(a).
# Биграмма ['плавно', 'летит'] встречается в тексте 1 раз(a).
