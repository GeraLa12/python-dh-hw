# %% [markdown]
# **Задание №1**
#
# Скачайте текст "Литературных анекдотов". Напишите функцию, которая будет читать файл, лемматизировать текст с помощью pymystem3 и записывать результат в новый файл. У функции должно бы два аргумента: путь к исходному файлу и путь к файлу с лемматизированным текстом. Вызов функции тоже должен быть прописан в решении.

# %%
from pymystem3 import Mystem
from string import punctuation

# %%
def lemmas(original, lemma_anecdotes): #создаем функцию и два аргумента
    f = open(original, 'r', encoding='utf-8') # чтение файла 
    poem = f.read()
    f.close()
    
    words = poem.split()
    no_punctuation1 = [w.strip(punctuation) for w in words] #убираем пунктуацию
    no_punctuation2 = [w.strip("—«»!...?-") for w in no_punctuation1] # убираем тире и другую не убранную пунктуацию
    cleanpoem = ' '.join(no_punctuation2)
    
    m = Mystem() #Лемматизация с помощью pymystem3
    lemmas = m.lemmatize(cleanpoem)
    lemma_poem = ''.join(lemmas)
    
    with open(lemma_anecdotes, 'w', encoding='utf-8') as f: # записать результат лемматизации в файл
        f.write(lemma_poem)

# %%
#вызов функции
lemmas(input("Путь к исходному файлу: "), input("Имя нового файла с лемматизированным текстом: "))
# Out:
# Путь к исходному файлу: literary_anecdotes.txt
# Имя нового файла с лемматизированным текстом: lemma_anecdotes4.txt

# %% [markdown]
# **Задание №2**
#
# Очистите лемматизированный текст от стоп-слов и посчитайте ipm (относительную частоту слов) для оставшихся. Выведите 20 самых частотных по этому параметру слов.

# %%
from collections import Counter

# %%
f = open('stopwords.txt', 'r', encoding='utf-8') # открываем файл со стоп-словами
stopwords = f.read()
f.close()

# %%
f = open("lemma_anecdotes4.txt", 'r', encoding='utf-8') # открываем файл с леммами
lemmatised_anecdotes = f.read()
f.close()
no_enter = [w.strip("\n") for w in lemmatised_anecdotes.split()] # на всякий случай еще обрежем переносы строки

# %%
#очищаем леммы от стоп слов и ненужных пробелов
stopwords = stopwords.split('\n')
clean_lemmas = [i for i in no_enter if i not in stopwords and i != " " and i != "  "] 
print(clean_lemmas [1:20])
# Out:
# ['квартира', 'окно', 'тверской', 'бульвар', 'пушкин', 'любить', 'ходить', 'гость', 'прийти', 'сразу', 'прыг', 'подоконник', 'свешиваться', 'окно', 'смотреть', 'чай', 'тоже', 'туда', 'окно']

# %%
# это абсолютная частота 
count_clean_lemmas = Counter(clean_lemmas)
print(count_clean_lemmas)
# Out:
# Counter({'пушкин': 59, 'толстой': 33, 'гоголь': 31, 'однажды': 29, 'лев': 25, 'любить': 20, 'достоевский': 20, 'тургенев': 16, 'ребенок': 15, 'царствие': 15, 'небесный': 15, 'окно': 12, 'тверской': 12, 'бульвар': 12, 'приходить': 12, 'лермонтов': 12, 'федор': 11, 'михайлович': 11, 'идти': 10, 'герцен': 10, 'человек': 10, 'переодеваться': 9, 'хорошо': 9, 'роман': 9, 'увидеть': 8, 'конечно': 8, 'знать': 8, 'собака': 8, 'сидеть': 8, 'гость': 7, 'смотреть': 7, 'тоже': 7, 'становиться': 7, 'писать': 7, 'костыль': 7, 'давать': 6, 'жизнь': 6, 'написать': 6, 'дом': 6, 'стих': 6, 'николай': 6, 'вяземский': 5, 'чай': 5, 'ночь': 5, 'кричать': 5, 'день': 5, 'хороший': 5, 'навстречу': 5, 'глаз': 5, 'чернышевский': 5, 'проходить': 5, 'купить': 4, 'жена': 4, 'бросаться': 4, 'мимо': 4, 'дама': 4, 'наталья': 4, 'николаевна': 4, 'нога': 4, 'лавка': 4, 'другой': 4, 'рука': 4, 'читать': 4, 'сдавать': 4, 'бывать': 4, 'бывало': 4, 'много': 4, 'время': 4, 'уезжать': 4, 'баден-баден': 4, 'кот': 4, 'прочитывать': 4, 'гений': 4, 'сразу': 3, 'подоконник': 3, 'подавать': 3, 'кавказ': 3, 'подумать': 3, 'догнать': 3, 'головка': 3, 'место': 3, 'яблоко': 3, 'александрина': 3, 'бежать': 3, 'александрин': 3, 'решать': 3, 'играть': 3, 'литературный': 3, 'письмо': 3, 'правда': 3, 'дело': 3, 'посмотреть': 3, 'сон': 3, 'будто': 3, 'держать': 3, 'отдавать': 3, 'часто': 3, 'приводить': 3, 'встречать': 3, 'всегда': 3, 'сабля': 3, 'спорить': 3, 'конь': 3, 'бог': 3, 'просыпаться': 3, 'большой': 3, 'бояться': 3, 'пить': 3, 'пора': 3, 'лира': 3, 'робкий': 3, 'васильевич': 3, 'никто': 3, 'бедный': 3, 'ходить': 2, 'матрац': 2, 'спать': 2, 'позвонить': 2, 'открывать': 2, 'зеркало': 2, 'революция': 2, 'пойти': 2, 'вставать': 2, 'смеяться': 2, 'стреляться': 2, 'первый': 2, 'погладить': 2, 'побежать': 2, 'литератор': 2, 'сторона': 2, 'угощать': 2, 'сестра': 2, 'задрожать': 2, 'собачка': 2, 'испугать': 2, 'спрятаться': 2, 'оба': 2, 'сделать': 2, 'возражать': 2, 'левушка': 2, 'война': 2, 'мир': 2, 'дорогой': 2, 'тагор': 2, 'познакомиться': 2, 'толкать': 2, 'подсовывать': 2, 'уметь': 2, 'год': 2, 'писатель': 2, 'каждый': 2, 'туз': 2, 'сдавать-ка': 2, 'брат': 2, 'шесть': 2, 'окурок': 2, 'ничто': 2, 'сниться': 2, 'лондон': 2, 'мертвый': 2, 'панихида': 2, 'конец': 2, 'душа': 2, 'задумываться': 2, 'проигрывать': 2, 'приходиться': 2, 'башка': 2, 'вид': 2, 'проза': 2, 'майков': 2, 'сергеевич': 2, 'давеча': 2, 'плакать': 2, 'штука': 2, 'сверху': 2, 'поехать': 2, 'крикнуть': 2, 'пассаж': 2, 'утро': 2, 'поймать': 2, 'череп': 2, 'треснуть': 2, 'рот': 2, 'открываться': 2, 'поэтому': 2, 'улыбаться': 2, 'например': 2, 'бакенбарда': 2, 'понимать': 2, 'плохой': 2, 'вспомнить': 2, 'уходить': 2, 'кабинет': 2, 'вечно': 2, 'мало': 2, 'шаг': 2, 'посылать': 2, 'иметь': 2, 'стол': 2, 'котлетка': 2, 'пиво': 2, 'испугаться': 2, 'оставаться': 2, 'совсем': 2, 'особенно': 2, 'красивый': 2, 'рубль': 2, 'дура': 2, 'нацепить': 2, 'покупать': 2, 'смотреть-ка': 2, 'сейчас': 2, 'нервный': 2, 'плохо': 2, 'зарезать': 2, 'рано': 2, 'улица': 2, 'животное': 2, 'визжать': 2, 'сзади': 2, 'лагерь': 2, 'павлович': 2, 'уголовник': 2, 'герой': 2, 'рукопись': 2, 'холодный': 2, 'пот': 2, 'отредактировать': 2, 'натурально': 2, 'черный': 2, 'вновь': 2, 'автор': 2, 'очки': 2, 'куст': 2, 'умирать': 2, 'кончаться': 2, 'квартира': 1, 'прийти': 1, 'прыг': 1, 'свешиваться': 1, 'туда': 1, 'иной': 1, 'заночевать': 1, 'специальный': 1, 'признавать."к': 1, 'роскошь': 1, 'спихивать': 1, 'вертеться': 1, 'арина': 1, 'родионовна': 1, 'уводить': 1, 'из-за': 1, 'колонна': 1, 'устыжаться': 1, 'желание': 1, 'русский': 1, 'свинья': 1, 'колено': 1, 'твой': 1, 'кинжал': 1, 'грудь': 1, 'стрелять': 1, 'впереди': 1, 'подросток': 1, 'равный': 1, 'догонять': 1, 'толстовский': 1, 'намерение': 1, 'наутек': 1, 'пробегать': 1, 'городовой': 1, 'сей': 1, 'страж': 1, 'порядок': 1, 'возмущать': 1, 'неприличный': 1, 'быстрота': 1, 'бега': 1, 'людный': 1, 'бегом': 1, 'устремляться': 1, 'вслед': 1, 'цель': 1, 'останавливать': 1, 'западный': 1, 'пресса': 1, 'росси ...

# %%
# посчитаем ipm (относительную частоту слов) для оставшихся лемм 
# это отношение его абсолютной частоты к какой-нибудь другой величине, например, к длине текста. 
# это отношение абсолютной частоты какого-либо элемента к объему корпуса, умноженное на миллион

ipm = {} #создаем словарь, куда будем считать частоту

for k,v in count_clean_lemmas.items():
    ipm[k] = v / len (lemmatised_anecdotes)  * 1000000 # lemmatised_anecdotes - это лемматизированный текст, еще не очищенный от стоп слов
print (ipm)
# Out:
# {'вяземский': 288.23427682019945, 'квартира': 57.64685536403989, 'окно': 691.7622643684787, 'тверской': 691.7622643684787, 'бульвар': 691.7622643684787, 'пушкин': 3401.164466478354, 'любить': 1152.9371072807978, 'ходить': 115.29371072807977, 'гость': 403.52798754827927, 'прийти': 57.64685536403989, 'сразу': 172.94056609211967, 'прыг': 57.64685536403989, 'подоконник': 172.94056609211967, 'свешиваться': 57.64685536403989, 'смотреть': 403.52798754827927, 'чай': 288.23427682019945, 'тоже': 403.52798754827927, 'туда': 57.64685536403989, 'подавать': 172.94056609211967, 'иной': 57.64685536403989, 'заночевать': 57.64685536403989, 'матрац': 115.29371072807977, 'купить': 230.58742145615955, 'специальный': 57.64685536403989, 'признавать."к': 57.64685536403989, 'роскошь': 57.64685536403989, 'спихивать': 57.64685536403989, 'ночь': 288.23427682019945, 'вертеться': 57.64685536403989, 'спать': 115.29371072807977, 'давать': 345.88113218423933, 'гоголь': 1787.0525162852366, 'переодеваться': 518.821698276359, 'приходить': 691.7622643684787, 'позвонить': 115.29371072807977, 'открывать': 115.29371072807977, 'кричать': 288.23427682019945, 'арина': 57.64685536403989, 'родионовна': 57.64685536403989, 'лермонтов': 691.7622643684787, 'жена': 230.58742145615955, 'уводить': 57.64685536403989, 'кавказ': 172.94056609211967, 'из-за': 57.64685536403989, 'колонна': 57.64685536403989, 'устыжаться': 57.64685536403989, 'желание': 57.64685536403989, 'зеркало': 115.29371072807977, 'русский': 57.64685536403989, 'революция': 115.29371072807977, 'свинья': 57.64685536403989, 'пойти': 115.29371072807977, 'вставать': 115.29371072807977, 'колено': 57.64685536403989, 'твой': 57.64685536403989, 'кинжал': 57.64685536403989, 'грудь': 57.64685536403989, 'смеяться': 115.29371072807977, 'однажды': 1671.7588055571568, 'стреляться': 115.29371072807977, 'стрелять': 57.64685536403989, 'первый': 115.29371072807977, 'становиться': 403.52798754827927, 'лев': 1441.1713841009973, 'толстой': 1902.3462270133164, 'ребенок': 864.7028304605983, 'идти': 576.4685536403989, 'увидеть': 461.1748429123191, 'впереди': 57.64685536403989, 'конечно': 461.1748429123191, 'подросток': 57.64685536403989, 'подумать': 172.94056609211967, 'равный': 57.64685536403989, 'догнать': 172.94056609211967, 'погладить': 115.29371072807977, 'головка': 172.94056609211967, 'побежать': 115.29371072807977, 'догонять': 57.64685536403989, 'знать': 461.1748429123191, 'толстовский': 57.64685536403989, 'намерение': 57.64685536403989, 'бросаться': 230.58742145615955, 'наутек': 57.64685536403989, 'пробегать': 57.64685536403989, 'мимо': 230.58742145615955, 'городовой': 57.64685536403989, 'сей': 57.64685536403989, 'страж': 57.64685536403989, 'порядок': 57.64685536403989, 'возмущать': 57.64685536403989, 'неприличный': 57.64685536403989, 'быстрота': 57.64685536403989, 'бега': 57.64685536403989, 'людный': 57.64685536403989, 'место': 172.94056609211967, 'бегом': 57.64685536403989, 'устремляться': 57.64685536403989, 'вслед': 57.64685536403989, 'цель': 57.64685536403989, 'останавливать': 57.64685536403989, 'западный': 57.64685536403989, 'пресса': 57.64685536403989, 'писать': 403.52798754827927, 'россия': 57.64685536403989, 'литератор': 115.29371072807977, 'подвергаться': 57.64685536403989, 'преследование': 57.64685536403989, 'сторона': 115.29371072807977, 'власть': 57.64685536403989, 'яблоко': 172.94056609211967, 'угощать': 115.29371072807977, 'присутствовать': 57.64685536403989, 'дама': 230.58742145615955, 'брать': 57.64685536403989, 'мерси': 57.64685536403989, 'подходить': 57.64685536403989, 'наталья': 230.58742145615955, 'николаевна': 230.58742145615955, 'сестра': 115.29371072807977, 'александрина': 172.94056609211967, 'волнение': 57.64685536403989, 'задрожать': 115.29371072807977, 'упасть': 57.64685536403989, 'нога': 230.58742145615955, 'собака': 461.1748429123191, 'схватывать': 57.64685536403989, 'бежать': 172.94056609211967, 'александрин': 172.94056609211967, 'впервые': 57.64685536403989, 'жизнь': 345.88113218423933, 'собачка': 115 ...

# %%
# отсортируем по частоте 
sorted_counts = sorted(ipm.items(), key=lambda x: x[1], reverse=True)
print(sorted_counts)
# Out:
# [('пушкин', 3401.164466478354), ('толстой', 1902.3462270133164), ('гоголь', 1787.0525162852366), ('однажды', 1671.7588055571568), ('лев', 1441.1713841009973), ('любить', 1152.9371072807978), ('достоевский', 1152.9371072807978), ('тургенев', 922.3496858246382), ('ребенок', 864.7028304605983), ('царствие', 864.7028304605983), ('небесный', 864.7028304605983), ('окно', 691.7622643684787), ('тверской', 691.7622643684787), ('бульвар', 691.7622643684787), ('приходить', 691.7622643684787), ('лермонтов', 691.7622643684787), ('федор', 634.1154090044388), ('михайлович', 634.1154090044388), ('идти', 576.4685536403989), ('герцен', 576.4685536403989), ('человек', 576.4685536403989), ('переодеваться', 518.821698276359), ('хорошо', 518.821698276359), ('роман', 518.821698276359), ('увидеть', 461.1748429123191), ('конечно', 461.1748429123191), ('знать', 461.1748429123191), ('собака', 461.1748429123191), ('сидеть', 461.1748429123191), ('гость', 403.52798754827927), ('смотреть', 403.52798754827927), ('тоже', 403.52798754827927), ('становиться', 403.52798754827927), ('писать', 403.52798754827927), ('костыль', 403.52798754827927), ('давать', 345.88113218423933), ('жизнь', 345.88113218423933), ('написать', 345.88113218423933), ('дом', 345.88113218423933), ('стих', 345.88113218423933), ('николай', 345.88113218423933), ('вяземский', 288.23427682019945), ('чай', 288.23427682019945), ('ночь', 288.23427682019945), ('кричать', 288.23427682019945), ('день', 288.23427682019945), ('хороший', 288.23427682019945), ('навстречу', 288.23427682019945), ('глаз', 288.23427682019945), ('чернышевский', 288.23427682019945), ('проходить', 288.23427682019945), ('купить', 230.58742145615955), ('жена', 230.58742145615955), ('бросаться', 230.58742145615955), ('мимо', 230.58742145615955), ('дама', 230.58742145615955), ('наталья', 230.58742145615955), ('николаевна', 230.58742145615955), ('нога', 230.58742145615955), ('лавка', 230.58742145615955), ('другой', 230.58742145615955), ('рука', 230.58742145615955), ('читать', 230.58742145615955), ('сдавать', 230.58742145615955), ('бывать', 230.58742145615955), ('бывало', 230.58742145615955), ('много', 230.58742145615955), ('время', 230.58742145615955), ('уезжать', 230.58742145615955), ('баден-баден', 230.58742145615955), ('кот', 230.58742145615955), ('прочитывать', 230.58742145615955), ('гений', 230.58742145615955), ('сразу', 172.94056609211967), ('подоконник', 172.94056609211967), ('подавать', 172.94056609211967), ('кавказ', 172.94056609211967), ('подумать', 172.94056609211967), ('догнать', 172.94056609211967), ('головка', 172.94056609211967), ('место', 172.94056609211967), ('яблоко', 172.94056609211967), ('александрина', 172.94056609211967), ('бежать', 172.94056609211967), ('александрин', 172.94056609211967), ('решать', 172.94056609211967), ('играть', 172.94056609211967), ('литературный', 172.94056609211967), ('письмо', 172.94056609211967), ('правда', 172.94056609211967), ('дело', 172.94056609211967), ('посмотреть', 172.94056609211967), ('сон', 172.94056609211967), ('будто', 172.94056609211967), ('держать', 172.94056609211967), ('отдавать', 172.94056609211967), ('часто', 172.94056609211967), ('приводить', 172.94056609211967), ('встречать', 172.94056609211967), ('всегда', 172.94056609211967), ('сабля', 172.94056609211967), ('спорить', 172.94056609211967), ('конь', 172.94056609211967), ('бог', 172.94056609211967), ('просыпаться', 172.94056609211967), ('большой', 172.94056609211967), ('бояться', 172.94056609211967), ('пить', 172.94056609211967), ('пора', 172.94056609211967), ('лира', 172.94056609211967), ('робкий', 172.94056609211967), ('васильевич', 172.94056609211967), ('никто', 172.94056609211967), ('бедный', 172.94056609211967), ('ходить', 115.29371072807977), ('матрац', 115.29371072807977), ('спать', 115.29371072807977), ('позвонить', 115.29371072807977), ('открывать', 115.29371072807977), ('зеркало', 115.29371072807977), ('революция', 115.29371072807977), ('пойти', 115.29371072807977), ('вставать', 115.29371072807977), ('смеятьс ...

# %%
# выведем 20 самых частотных по этому параметру слов 
print(sorted_counts[:20])
# Out:
# [('пушкин', 3401.164466478354), ('толстой', 1902.3462270133164), ('гоголь', 1787.0525162852366), ('однажды', 1671.7588055571568), ('лев', 1441.1713841009973), ('любить', 1152.9371072807978), ('достоевский', 1152.9371072807978), ('тургенев', 922.3496858246382), ('ребенок', 864.7028304605983), ('царствие', 864.7028304605983), ('небесный', 864.7028304605983), ('окно', 691.7622643684787), ('тверской', 691.7622643684787), ('бульвар', 691.7622643684787), ('приходить', 691.7622643684787), ('лермонтов', 691.7622643684787), ('федор', 634.1154090044388), ('михайлович', 634.1154090044388), ('идти', 576.4685536403989), ('герцен', 576.4685536403989)]

# %%
# а тут 20 самых частотных, если считать по абсолютной частоте
count_clean_lemmas = Counter(clean_lemmas)
print(count_clean_lemmas.most_common(20))
# Out:
# [('пушкин', 59), ('толстой', 33), ('гоголь', 31), ('однажды', 29), ('лев', 25), ('любить', 20), ('достоевский', 20), ('тургенев', 16), ('ребенок', 15), ('царствие', 15), ('небесный', 15), ('окно', 12), ('тверской', 12), ('бульвар', 12), ('приходить', 12), ('лермонтов', 12), ('федор', 11), ('михайлович', 11), ('идти', 10), ('герцен', 10)]

# %% [markdown]
# **Задание №3**
#
# Сделайте полный морфологический разбор исходного текста. Напишите регулярное выражение, которое будет извлекать из тега только часть речи. Пройдитесь циклом по списку с разборами, который выдал pymystem3, извлекая из каждого разбора форму слова и его часть речи и записывая их в новый словарь (форма -- ключ, часть речи -- значение). Посчитайте абсолютную частоту для всех частей речи, а затем относительнную частоту (абсолютная частота / длина текста в словах).

# %%
import json
from pymystem3 import Mystem
import re

# %%
f = open('literary_anecdotes.txt', 'r', encoding='utf-8') #открываем изначальный файл
text = f.read()
f.close()

# %%
# производим анализ текста 
m = Mystem()
analysis_anecdotes = m.analyze(text)

# %%
words = {} # словарь, содержащий только грамматику
for word in analysis_anecdotes:
    try:
        form = word["text"]
        grammar = word ["analysis"] [0] ["gr"]
        words[form] = grammar
    except KeyError:
        pass
    except IndexError:
        pass

# %%
pos = re.compile('[A-Z]+') # регулярное выражение, которое будет извлекать из тега только части речи

# %%
words_pos = {} # пустой словарь, чтобы туда записывались значения

for k,v in words.items():
    words_pos[k] = pos.match(v).group(0)
print (words_pos)
# Out:
# {'У': 'PR', 'Вяземского': 'S', 'была': 'V', 'квартира': 'S', 'окнами': 'S', 'на': 'PR', 'Тверской': 'A', 'бульвар': 'S', 'Пушкин': 'S', 'очень': 'ADV', 'любил': 'V', 'ходить': 'V', 'к': 'PR', 'нему': 'SPRO', 'в': 'PR', 'гости': 'S', 'Придет': 'V', 'и': 'CONJ', 'сразу': 'ADV', 'прыг': 'ADV', 'подоконник': 'S', 'свесится': 'V', 'из': 'PR', 'окна': 'S', 'смотрит': 'V', 'Чай': 'S', 'ему': 'SPRO', 'тоже': 'PART', 'туда': 'ADVPRO', 'окно': 'S', 'подавали': 'V', 'Иной': 'APRO', 'раз': 'S', 'там': 'ADVPRO', 'заночует': 'V', 'Ему': 'SPRO', 'даже': 'PART', 'матрац': 'S', 'купили': 'V', 'специальный': 'A', 'только': 'PART', 'он': 'SPRO', 'его': 'SPRO', 'не': 'PART', 'признавал': 'V', 'К': 'PR', 'чему': 'SPRO', 'говорит': 'V', 'такие': 'APRO', 'роскоши': 'S', 'И': 'CONJ', 'спихнет': 'V', 'с': 'PR', 'подоконника': 'S', 'А': 'CONJ', 'потом': 'ADVPRO', 'всю': 'APRO', 'ночь': 'S', 'вертится': 'V', 'спать': 'V', 'дает': 'V', 'Гоголь': 'S', 'переоделся': 'V', 'Пушкиным': 'S', 'пришел': 'V', 'Пушкину': 'S', 'позвонил': 'V', 'открыл': 'V', 'кричит': 'V', 'Смотри': 'V', 'Арина': 'S', 'Родионовна': 'S', 'я': 'SPRO', 'Лермонтов': 'S', 'хотел': 'V', 'у': 'PR', 'Пушкина': 'S', 'жену': 'S', 'увести': 'V', 'На': 'PR', 'Кавказ': 'S', 'Все': 'APRO', 'смотрел': 'V', 'нее': 'SPRO', 'из-за': 'PR', 'колонн': 'S', 'Вдруг': 'ADV', 'устыдился': 'V', 'своих': 'APRO', 'желаний': 'S', 'думает': 'V', 'зеркало': 'S', 'русской': 'A', 'революции': 'S', 'а': 'CONJ', 'свинья': 'S', 'Пошел': 'V', 'встал': 'V', 'перед': 'PR', 'ним': 'SPRO', 'колени': 'S', 'где': 'ADVPRO', 'твой': 'APRO', 'кинжал': 'S', 'Вот': 'PART', 'грудь': 'S', 'моя': 'APRO', 'смеялся': 'V', 'Однажды': 'ADV', 'стрелялся': 'V', 'Гоголем': 'S', 'Стреляй': 'V', 'первым': 'ANUM', 'ты': 'SPRO', 'Как': 'ADVPRO', 'Нет': 'PART', 'Ах': 'INTJ', 'Так': 'ADVPRO', 'стали': 'V', 'стреляться': 'V', 'Лев': 'S', 'Толстой': 'S', 'детей': 'S', 'шел': 'V', 'по': 'PR', 'Тверскому': 'A', 'бульвару': 'S', 'увидел': 'V', 'впереди': 'PR', 'Конечно': 'ADV', 'это': 'SPRO', 'уже': 'ADV', 'ребенок': 'S', 'подросток': 'S', 'подумал': 'V', 'все': 'SPRO', 'равно': 'A', 'дай': 'V', 'догоню': 'V', 'поглажу': 'V', 'головке': 'S', 'побежал': 'V', 'догонять': 'V', 'же': 'PART', 'зная': 'V', 'толстовских': 'A', 'намерений': 'S', 'бросился': 'V', 'наутек': 'ADV', 'Пробегая': 'V', 'мимо': 'ADV', 'городового': 'S', 'сей': 'APRO', 'страж': 'S', 'порядка': 'S', 'был': 'V', 'возмущен': 'V', 'неприличной': 'A', 'быстротою': 'S', 'бега': 'S', 'людном': 'A', 'месте': 'S', 'бегом': 'ADV', 'устремился': 'V', 'вслед': 'ADV', 'целью': 'S', 'остановить': 'V', 'Западная': 'A', 'пресса': 'S', 'писала': 'V', 'что': 'CONJ', 'России': 'S', 'литераторы': 'S', 'подвергаются': 'V', 'преследованиям': 'S', 'со': 'PR', 'стороны': 'S', 'властей': 'S', 'купил': 'V', 'яблок': 'S', 'стал': 'V', 'угощать': 'V', 'присутствующих': 'V', 'дам': 'S', 'брали': 'V', 'говорили': 'V', 'мерси': 'S', 'Когда': 'ADVPRO', 'подошла': 'V', 'Наталья': 'S', 'Николаевна': 'S', 'сестрой': 'S', 'Александриной': 'S', 'от': 'PR', 'волненья': 'S', 'так': 'ADVPRO', 'задрожал': 'V', 'яблоко': 'S', 'упало': 'V', 'ее': 'SPRO', 'ногам': 'S', 'Натальи': 'S', 'Николаевны': 'S', 'Александрины': 'S', 'Одна': 'APRO', 'собак': 'S', 'схватила': 'V', 'бросилась': 'V', 'бежать': 'V', 'Александрина': 'S', 'конечно': 'ADV', 'побежала': 'V', 'за': 'PR', 'ней': 'SPRO', 'Они': 'SPRO', 'были': 'V', 'одни': 'APRO', 'впервые': 'ADV', 'жизни': 'S', 'собачкой': 'S', 'Кстати': 'ADV', 'она': 'SPRO', 'догнала': 'V', 'решил': 'V', 'испугать': 'V', 'Тургенева': 'S', 'спрятался': 'V', 'Тверском': 'A', 'бульваре': 'S', 'под': 'PR', 'лавкой': 'S', 'этот': 'APRO', 'день': 'S', 'другой': 'APRO', 'Тут': 'ADVPRO', 'Тургенев': 'S', 'идет': 'V', 'они': 'SPRO', 'оба': 'NUM', 'выскочат': 'V', 'играл': 'V', 'ними': 'SPRO', 'весь': 'APRO', 'проголодался': 'V', 'Сонечка': 'S', 'ангелочек': 'S', 'сделай': 'V', 'мне': 'SPRO', 'тюрьку': 'S', 'Она': 'SPRO', 'возражает': 'V', 'Левушка': 'S', 'видишь': 'V', 'Войну': 'S', 'мир': 'S', 'перепис ...

# %% [markdown]
# Посчитайте абсолютную частоту для всех частей речи, а затем относительнную частоту (абсолютная частота / длина текста в словах).

# %%
# посчитаем абсолютную частоту. 
# Создаем словарь, в котором при каждом проходе будет считаться количество частей речи
abs_freq = {}

for v in words_pos.values():
    if v in abs_freq:
        abs_freq [v] += 1
    else:
        abs_freq [v] = 1
print(abs_freq)
# Out:
# {'PR': 37, 'S': 440, 'V': 436, 'A': 100, 'ADV': 87, 'SPRO': 54, 'CONJ': 20, 'PART': 28, 'ADVPRO': 24, 'APRO': 51, 'ANUM': 2, 'INTJ': 7, 'NUM': 9}

# %%
# относительная частота

ipm_pos_freq = {}

for k,v in abs_freq.items():
    ipm_pos_freq[k] = v / len (text.split()) * 1000000
print (ipm_pos_freq)
# Out:
# {'PR': 13028.169014084508, 'S': 154929.57746478872, 'V': 153521.12676056338, 'A': 35211.2676056338, 'ADV': 30633.80281690141, 'SPRO': 19014.08450704225, 'CONJ': 7042.2535211267605, 'PART': 9859.154929577466, 'ADVPRO': 8450.704225352112, 'APRO': 17957.74647887324, 'ANUM': 704.2253521126761, 'INTJ': 2464.7887323943664, 'NUM': 3169.0140845070423}
